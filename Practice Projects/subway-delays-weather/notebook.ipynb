# %% [markdown]
# # Analyzing High-Speed Railway Delays Project
#
# - [View Solution Notebook](./solution.html)
# - [View Project Page](https://www.codecademy.com/projects/practice/analyzing-high-speed-railways-with-python)

# %% [markdown]
# ## Task Group 1 - Load and Clean

# %%
# Setup
import pandas as pd

df0 = pd.read_csv('datasets/railway_delays_2020_01_1.csv')
df0.head()
# Out:
#          date           ride_id train_number  station_order  \
# 0  2020-01-01  G1226_20200101_1        G1226            1.0
# 1  2020-01-01  G1226_20200101_2        G1226            2.0
# 2  2020-01-01  G1226_20200101_3        G1226            3.0
# 3  2020-01-01  G1226_20200101_4        G1226            4.0
# 4  2020-01-01  G1226_20200101_5        G1226            5.0
#
#                   station_name                  to_station  mileage  \
# 0  Shenyangbei Railway Station    Shenyang Railway Station      5.0
# 1     Shenyang Railway Station    Liaoyang Railway Station     65.0
# 2     Liaoyang Railway Station    Anshanxi Railway Station     30.0
# 3     Anshanxi Railway Station  Haichengxi Railway Station     39.0
# 4   Haichengxi Railway Station      Panjin Railway Station     66.0
#
#    arrival_delay  departure_delay  major_holiday
# 0            0.0             -1.0           True
# 1           -2.0              2.0           True
# 2            4.0              4.0           True
# 3            5.0              4.0           True
# 4            5.0              4.0           True

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What is the structure of this dataset? Toggle to check!</i></summary>
#
# Each row contains departure and arrival delays for trains in China on January 1st, 2020.
#
# Here's a quick summary of the columns:
#
# - **date** - the date of the train ride
# - **ride_id** - the unique identifier for each train ride: `<train_number>_<yyyymmdd>_<station_order>`
# - **train_number** - a unique identifier of the train
# - **station_order** - the order in which each station was visited in a train route by a single train number on a specific date
# - **station_name** - the name of the departing station
# - **to_station** - the name of the next station destination
# - **mileage** - the distance in kilometers to the next station
# - **arrival_delay** - the delay in minutes arriving to the next station
# - **departure_delay** - the delay in minutes departing the current station
# - **major_holiday** - `True` if the `date` is a major holiday
#
# </details>

# %% [markdown]
# ### Task 1
#
# Each day in January has its own data file. The names of these files depend on the date. For example, the file we read in above is `datasets/railway_delays_2020_01_1.csv`, corresponding to the day `2020-01-1`, or January 1st.
#
# Use a list comprehension to create a list of the filenames from January 1st, 2020 to January 27th, 2020. Name this list `filenames` and print out the list.

# %%
filenames = ['datasets/railway_delays_2020_01_' + str(i) + '.csv' for i in range(1,28)]
filenames
# Out:
# ['datasets/railway_delays_2020_01_1.csv',
#  'datasets/railway_delays_2020_01_2.csv',
#  'datasets/railway_delays_2020_01_3.csv',
#  'datasets/railway_delays_2020_01_4.csv',
#  'datasets/railway_delays_2020_01_5.csv',
#  'datasets/railway_delays_2020_01_6.csv',
#  'datasets/railway_delays_2020_01_7.csv',
#  'datasets/railway_delays_2020_01_8.csv',
#  'datasets/railway_delays_2020_01_9.csv',
#  'datasets/railway_delays_2020_01_10.csv',
#  'datasets/railway_delays_2020_01_11.csv',
#  'datasets/railway_delays_2020_01_12.csv',
#  'datasets/railway_delays_2020_01_13.csv',
#  'datasets/railway_delays_2020_01_14.csv',
#  'datasets/railway_delays_2020_01_15.csv',
#  'datasets/railway_delays_2020_01_16.csv',
#  'datasets/railway_delays_2020_01_17.csv',
#  'datasets/railway_delays_2020_01_18.csv',
#  'datasets/railway_delays_2020_01_19.csv',
#  'datasets/railway_delays_2020_01_20.csv',
#  'datasets/railway_delays_2020_01_21.csv',
#  'datasets/railway_delays_2020_01_22.csv',
#  'datasets/railway_delays_2020_01_23.csv',
#  'datasets/railway_delays_2020_01_24.csv',
#  'datasets/railway_delays_2020_01_25.csv',
#  'datasets/railway_delays_2020_01_26.csv',
#  'datasets/railway_delays_2020_01_27.csv']

# %% [markdown]
# ### Task 2
#
# Now that we have a list of filenames, we can import them as DataFrames. Use a list comprehension to create a list of DataFrames named `railway_delays_dfs`. Print summary information about the first DataFrame and take a look at the column names and their datatypes.

# %%
railway_delays_df = [pd.read_csv(x) for x in filenames]
railway_delays_df
# Out:
# [            date           ride_id train_number  station_order  \
#  0     2020-01-01  G1226_20200101_1        G1226            1.0
#  1     2020-01-01  G1226_20200101_2        G1226            2.0
#  2     2020-01-01  G1226_20200101_3        G1226            3.0
#  3     2020-01-01  G1226_20200101_4        G1226            4.0
#  4     2020-01-01  G1226_20200101_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-01  G868_20200101_24         G868           24.0
#  1107  2020-01-01  G868_20200101_25         G868           25.0
#  1108  2020-01-01  G868_20200101_26         G868           26.0
#  1109  2020-01-01  G868_20200101_27         G868           27.0
#  1110  2020-01-01  G868_20200101_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0           True
#  1              -2.0              2.0           True
#  2               4.0              4.0           True
#  3               5.0              4.0           True
#  4               5.0              4.0           True
#  ...             ...              ...            ...
#  1106           -3.0             -3.0           True
#  1107           -2.0             -2.0           True
#  1108           -2.0             -3.0           True
#  1109           -3.0             -2.0           True
#  1110           -3.0             -2.0           True
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-02  G1226_20200102_1        G1226            1.0
#  1     2020-01-02  G1226_20200102_2        G1226            2.0
#  2     2020-01-02  G1226_20200102_3        G1226            3.0
#  3     2020-01-02  G1226_20200102_4        G1226            4.0
#  4     2020-01-02  G1226_20200102_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-02  G868_20200102_24         G868           24.0
#  1107  2020-01-02  G868_20200102_25         G868           25.0
#  1108  2020-01-02  G868_20200102_26         G868           26.0
#  1109  2020-01-02  G868_20200102_27         G868           27.0
#  1110  2020-01-02  G868_20200102_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0           True
#  1              -2.0              2.0           True
#  2               2.0              2.0           True
#  3               5.0              4.0           True
#  4               4.0              3.0           True
#  ...             ...              ...            ...
#  1106           -3.0             -2.0           True
#  1107           -2.0             -1.0           True
#  1108           -1.0             -2.0           True
#  1109           -1.0             -1.0           True
#  1110           -3.0             -2.0           True
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-03  G1226_20200103_1        G1226            1.0
#  1     2020-01-03  G1226_20200103_2        G1226            2.0
#  2     2020-01-03  G1226_20200103_3        G1226            3.0
#  3     2020-01-03  G1226_20200103_4        G1226            4.0
#  4     2020-01-03  G1226_20200103_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-03  G868_20200103_24         G868           24.0
#  1107  2020-01-03  G868_20200103_25         G868           25.0
#  1108  2020-01-03  G868_20200103_26         G868           26.0
#  1109  2020-01-03  G868_20200103_27         G868           27.0
#  1110  2020-01-03  G868_20200103_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              1.0          False
#  2               1.0              1.0          False
#  3               3.0              2.0          False
#  4               3.0              2.0          False
#  ...             ...              ...            ...
#  1106           -3.0             -2.0          False
#  1107           -1.0             -1.0          False
#  1108            0.0             -1.0          False
#  1109           -1.0             -1.0          False
#  1110           -1.0             -2.0          False
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-04  G1226_20200104_1        G1226            1.0
#  1     2020-01-04  G1226_20200104_2        G1226            2.0
#  2     2020-01-04  G1226_20200104_3        G1226            3.0
#  3     2020-01-04  G1226_20200104_4        G1226            4.0
#  4     2020-01-04  G1226_20200104_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-04  G868_20200104_24         G868           24.0
#  1107  2020-01-04  G868_20200104_25         G868           25.0
#  1108  2020-01-04  G868_20200104_26         G868           26.0
#  1109  2020-01-04  G868_20200104_27         G868           27.0
#  1110  2020-01-04  G868_20200104_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              0.0          False
#  2               0.0              0.0          False
#  3               2.0              1.0          False
#  4               1.0              0.0          False
#  ...             ...              ...            ...
#  1106           -3.0              1.0          False
#  1107            9.0              8.0          False
#  1108            8.0              9.0          False
#  1109           10.0             10.0          False
#  1110           13.0             11.0          False
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-05  G1226_20200105_1        G1226            1.0
#  1     2020-01-05  G1226_20200105_2        G1226            2.0
#  2     2020-01-05  G1226_20200105_3        G1226            3.0
#  3     2020-01-05  G1226_20200105_4        G1226            4.0
#  4     2020-01-05  G1226_20200105_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-05  G868_20200105_24         G868           24.0
#  1107  2020-01-05  G868_20200105_25         G868           25.0
#  1108  2020-01-05  G868_20200105_26         G868           26.0
#  1109  2020-01-05  G868_20200105_27         G868           27.0
#  1110  2020-01-05  G868_20200105_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              0.0          False
#  2               0.0              0.0          False
#  3               2.0              1.0          False
#  4               2.0              1.0          False
#  ...             ...              ...            ...
#  1106            1.0              0.0          False
#  1107            2.0              2.0          False
#  1108            9.0              8.0          False
#  1109           24.0             24.0          False
#  1110           23.0             22.0          False
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-06  G1226_20200106_1        G1226            1.0
#  1     2020-01-06  G1226_20200106_2        G1226            2.0
#  2     2020-01-06  G1226_20200106_3        G1226            3.0
#  3     2020-01-06  G1226_20200106_4        G1226            4.0
#  4     2020-01-06  G1226_20200106_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-06  G868_20200106_24         G868           24.0
#  1107  2020-01-06  G868_20200106_25         G868           25.0
#  1108  2020-01-06  G868_20200106_26         G868           26.0
#  1109  2020-01-06  G868_20200106_27         G868           27.0
#  1110  2020-01-06  G868_20200106_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              0.0          False
#  2               0.0              0.0          False
#  3               3.0              2.0          False
#  4               1.0              0.0          False
#  ...             ...              ...            ...
#  1106           -1.0             -2.0          False
#  1107            1.0              1.0          False
#  1108            8.0              7.0          False
#  1109           19.0             18.0          False
#  1110           17.0             15.0          False
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-07  G1226_20200107_1        G1226            1.0
#  1     2020-01-07  G1226_20200107_2        G1226            2.0
#  2     2020-01-07  G1226_20200107_3        G1226            3.0
#  3     2020-01-07  G1226_20200107_4        G1226            4.0
#  4     2020-01-07  G1226_20200107_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-07  G868_20200107_24         G868           24.0
#  1107  2020-01-07  G868_20200107_25         G868           25.0
#  1108  2020-01-07  G868_20200107_26         G868           26.0
#  1109  2020-01-07  G868_20200107_27         G868           27.0
#  1110  2020-01-07  G868_20200107_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2              -2.0             -1.0          False
#  3               1.0              0.0          False
#  4               1.0              0.0          False
#  ...             ...              ...            ...
#  1106           -1.0             -1.0          False
#  1107           11.0             11.0          False
#  1108           25.0             25.0          False
#  1109            1.0              0.0          False
#  1110           -1.0             -2.0          False
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-08  G1226_20200108_1        G1226            1.0
#  1     2020-01-08  G1226_20200108_2        G1226            2.0
#  2     2020-01-08  G1226_20200108_3        G1226            3.0
#  3     2020-01-08  G1226_20200108_4        G1226            4.0
#  4     2020-01-08  G1226_20200108_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-08  G868_20200108_24         G868           24.0
#  1107  2020-01-08  G868_20200108_25         G868           25.0
#  1108  2020-01-08  G868_20200108_26         G868           26.0
#  1109  2020-01-08  G868_20200108_27         G868           27.0
#  1110  2020-01-08  G868_20200108_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              2.0          False
#  2               7.0              7.0          False
#  3              11.0             10.0          False
#  4              11.0             10.0          False
#  ...             ...              ...            ...
#  1106            1.0              0.0          False
#  1107           -1.0             -1.0          False
#  1108            1.0              0.0          False
#  1109            1.0              0.0          False
#  1110           -1.0             -2.0          False
#
#  [1111 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-09  G1226_20200109_1        G1226            1.0
#  1     2020-01-09  G1226_20200109_2        G1226            2.0
#  2     2020-01-09  G1226_20200109_3        G1226            3.0
#  3     2020-01-09  G1226_20200109_4        G1226            4.0
#  4     2020-01-09  G1226_20200109_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1106  2020-01-09  G868_20200109_24         G868           24.0
#  1107  2020-01-09  G868_20200109_25         G868           25.0
#  1108  2020-01-09  G868_20200109_26         G868           26.0
#  1109  2020-01-09  G868_20200109_27         G868           27.0
#  1110  2020-01-09  G868_20200109_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1106     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1107  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1108       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1109      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1110       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2              -2.0             -1.0          False
#  3               1.0              0.0          False
#  4               1.0              0.0          False
#  ...             ...              ...            ...
#  1106            1.0              0.0          False
#  1107            0.0              0.0          False
#  1108            1.0              0.0          False
#  1109            0.0             -1.0          False
#  1110           -2.0             -3.0          False
#
#  [1111 rows x 10 columns],
#              DATE           RIDE_ID TRAIN_NUMBER  STATION_ORDER  \
#  0     2020-01-10  G1226_20200110_1        G1226              1
#  1     2020-01-10  G1226_20200110_2        G1226              2
#  2     2020-01-10  G1226_20200110_3        G1226              3
#  3     2020-01-10  G1226_20200110_4        G1226              4
#  4     2020-01-10  G1226_20200110_5        G1226              5
#  ...          ...               ...          ...            ...
#  1108  2020-01-10  G868_20200110_24         G868             24
#  1109  2020-01-10  G868_20200110_25         G868             25
#  1110  2020-01-10  G868_20200110_26         G868             26
#  1111  2020-01-10  G868_20200110_27         G868             27
#  1112  2020-01-10  G868_20200110_28         G868             28
#
#                          STATION_NAME                      TO_STATION  MILEAGE  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station        5
#  1           Shenyang Railway Station        Liaoyang Railway Station       65
#  2           Liaoyang Railway Station        Anshanxi Railway Station       30
#  3           Anshanxi Railway Station      Haichengxi Railway Station       39
#  4         Haichengxi Railway Station          Panjin Railway Station       66
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station       46
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station       65
#  1110       Minchinan Railway Station      Huashanbei Railway Station      194
#  1111      Huashanbei Railway Station       Weinanbei Railway Station       58
#  1112       Weinanbei Railway Station         Xianbei Railway Station       63
#
#        ARRIVAL_DELAY  DEPARTURE_DELAY  MAJOR_HOLIDAY
#  0                 0               -1          False
#  1                -2                3          False
#  2                 4                4          False
#  3                 6                5          False
#  4                 6                5          False
#  ...             ...              ...            ...
#  1108             -1               -1          False
#  1109             -1                0          False
#  1110              1                0          False
#  1111             -1               -1          False
#  1112             -2               -3          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-11  G1226_20200111_1        G1226            1.0
#  1     2020-01-11  G1226_20200111_2        G1226            2.0
#  2     2020-01-11  G1226_20200111_3        G1226            3.0
#  3     2020-01-11  G1226_20200111_4        G1226            4.0
#  4     2020-01-11  G1226_20200111_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-11  G868_20200111_24         G868           24.0
#  1109  2020-01-11  G868_20200111_25         G868           25.0
#  1110  2020-01-11  G868_20200111_26         G868           26.0
#  1111  2020-01-11  G868_20200111_27         G868           27.0
#  1112  2020-01-11  G868_20200111_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              1.0          False
#  2               1.0              1.0          False
#  3               3.0              5.0          False
#  4               7.0              6.0          False
#  ...             ...              ...            ...
#  1108            1.0              0.0          False
#  1109            1.0              0.0          False
#  1110            2.0              1.0          False
#  1111            0.0             -1.0          False
#  1112            0.0             -2.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-12  G1226_20200112_1        G1226            1.0
#  1     2020-01-12  G1226_20200112_2        G1226            2.0
#  2     2020-01-12  G1226_20200112_3        G1226            3.0
#  3     2020-01-12  G1226_20200112_4        G1226            4.0
#  4     2020-01-12  G1226_20200112_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-12  G868_20200112_24         G868           24.0
#  1109  2020-01-12  G868_20200112_25         G868           25.0
#  1110  2020-01-12  G868_20200112_26         G868           26.0
#  1111  2020-01-12  G868_20200112_27         G868           27.0
#  1112  2020-01-12  G868_20200112_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -3.0              0.0          False
#  2               0.0              0.0          False
#  3               2.0              1.0          False
#  4               1.0              0.0          False
#  ...             ...              ...            ...
#  1108            0.0             -1.0          False
#  1109            0.0              0.0          False
#  1110            2.0              1.0          False
#  1111            1.0              0.0          False
#  1112            0.0             -2.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-13  G1226_20200113_1        G1226            1.0
#  1     2020-01-13  G1226_20200113_2        G1226            2.0
#  2     2020-01-13  G1226_20200113_3        G1226            3.0
#  3     2020-01-13  G1226_20200113_4        G1226            4.0
#  4     2020-01-13  G1226_20200113_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1066  2020-01-13  G868_20200113_24         G868           24.0
#  1067  2020-01-13  G868_20200113_25         G868           25.0
#  1068  2020-01-13  G868_20200113_26         G868           26.0
#  1069  2020-01-13  G868_20200113_27         G868           27.0
#  1070  2020-01-13  G868_20200113_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1066     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1067  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1068       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1069      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1070       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -1.0              0.0          False
#  2               0.0              0.0          False
#  3               1.0              0.0          False
#  4               1.0              0.0          False
#  ...             ...              ...            ...
#  1066            1.0              0.0          False
#  1067            0.0              0.0          False
#  1068            1.0              0.0          False
#  1069            0.0             -1.0          False
#  1070           -1.0             -2.0          False
#
#  [1071 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-14  G1226_20200114_1        G1226            1.0
#  1     2020-01-14  G1226_20200114_2        G1226            2.0
#  2     2020-01-14  G1226_20200114_3        G1226            3.0
#  3     2020-01-14  G1226_20200114_4        G1226            4.0
#  4     2020-01-14  G1226_20200114_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-14  G868_20200114_24         G868           24.0
#  1109  2020-01-14  G868_20200114_25         G868           25.0
#  1110  2020-01-14  G868_20200114_26         G868           26.0
#  1111  2020-01-14  G868_20200114_27         G868           27.0
#  1112  2020-01-14  G868_20200114_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              0.0          False
#  2              -1.0             -1.0          False
#  3               2.0              1.0          False
#  4               2.0              1.0          False
#  ...             ...              ...            ...
#  1108            0.0             -1.0          False
#  1109           -1.0              0.0          False
#  1110            1.0              0.0          False
#  1111            0.0             -1.0          False
#  1112           -1.0             -1.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-15  G1226_20200115_1        G1226            1.0
#  1     2020-01-15  G1226_20200115_2        G1226            2.0
#  2     2020-01-15  G1226_20200115_3        G1226            3.0
#  3     2020-01-15  G1226_20200115_4        G1226            4.0
#  4     2020-01-15  G1226_20200115_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-15  G868_20200115_24         G868           24.0
#  1109  2020-01-15  G868_20200115_25         G868           25.0
#  1110  2020-01-15  G868_20200115_26         G868           26.0
#  1111  2020-01-15  G868_20200115_27         G868           27.0
#  1112  2020-01-15  G868_20200115_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              0.0          False
#  2               3.0              3.0          False
#  3               5.0              5.0          False
#  4               4.0              3.0          False
#  ...             ...              ...            ...
#  1108            0.0             -1.0          False
#  1109           -1.0              0.0          False
#  1110            1.0              0.0          False
#  1111            1.0              0.0          False
#  1112            1.0             -1.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-16  G1226_20200116_1        G1226            1.0
#  1     2020-01-16  G1226_20200116_2        G1226            2.0
#  2     2020-01-16  G1226_20200116_3        G1226            3.0
#  3     2020-01-16  G1226_20200116_4        G1226            4.0
#  4     2020-01-16  G1226_20200116_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-16  G868_20200116_24         G868           24.0
#  1109  2020-01-16  G868_20200116_25         G868           25.0
#  1110  2020-01-16  G868_20200116_26         G868           26.0
#  1111  2020-01-16  G868_20200116_27         G868           27.0
#  1112  2020-01-16  G868_20200116_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2               1.0              1.0          False
#  3               3.0              2.0          False
#  4               3.0              2.0          False
#  ...             ...              ...            ...
#  1108            7.0             11.0          False
#  1109           13.0             14.0          False
#  1110           16.0             15.0          False
#  1111           25.0             24.0          False
#  1112           24.0             22.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-17  G1226_20200117_1        G1226            1.0
#  1     2020-01-17  G1226_20200117_2        G1226            2.0
#  2     2020-01-17  G1226_20200117_3        G1226            3.0
#  3     2020-01-17  G1226_20200117_4        G1226            4.0
#  4     2020-01-17  G1226_20200117_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-17  G868_20200117_24         G868           24.0
#  1109  2020-01-17  G868_20200117_25         G868           25.0
#  1110  2020-01-17  G868_20200117_26         G868           26.0
#  1111  2020-01-17  G868_20200117_27         G868           27.0
#  1112  2020-01-17  G868_20200117_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2              -1.0             -1.0          False
#  3               0.0             -1.0          False
#  4               0.0             -1.0          False
#  ...             ...              ...            ...
#  1108           -1.0             -1.0          False
#  1109           -1.0             -1.0          False
#  1110            1.0              0.0          False
#  1111            0.0             -1.0          False
#  1112           -1.0             -2.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-18  G1226_20200118_1        G1226            1.0
#  1     2020-01-18  G1226_20200118_2        G1226            2.0
#  2     2020-01-18  G1226_20200118_3        G1226            3.0
#  3     2020-01-18  G1226_20200118_4        G1226            4.0
#  4     2020-01-18  G1226_20200118_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-18  G868_20200118_24         G868           24.0
#  1109  2020-01-18  G868_20200118_25         G868           25.0
#  1110  2020-01-18  G868_20200118_26         G868           26.0
#  1111  2020-01-18  G868_20200118_27         G868           27.0
#  1112  2020-01-18  G868_20200118_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2              -1.0             -1.0          False
#  3               2.0              2.0          False
#  4               2.0              1.0          False
#  ...             ...              ...            ...
#  1108           -1.0             -1.0          False
#  1109           -1.0              0.0          False
#  1110            1.0              0.0          False
#  1111            0.0              0.0          False
#  1112            0.0             -1.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-19  G1226_20200119_1        G1226            1.0
#  1     2020-01-19  G1226_20200119_2        G1226            2.0
#  2     2020-01-19  G1226_20200119_3        G1226            3.0
#  3     2020-01-19  G1226_20200119_4        G1226            4.0
#  4     2020-01-19  G1226_20200119_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-19  G868_20200119_24         G868           24.0
#  1109  2020-01-19  G868_20200119_25         G868           25.0
#  1110  2020-01-19  G868_20200119_26         G868           26.0
#  1111  2020-01-19  G868_20200119_27         G868           27.0
#  1112  2020-01-19  G868_20200119_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0              0.0          False
#  2               2.0              2.0          False
#  3               5.0              4.0          False
#  4               5.0              4.0          False
#  ...             ...              ...            ...
#  1108            6.0              5.0          False
#  1109            5.0              5.0          False
#  1110            6.0              5.0          False
#  1111            5.0              4.0          False
#  1112            4.0              2.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-20  G1226_20200120_1        G1226            1.0
#  1     2020-01-20  G1226_20200120_2        G1226            2.0
#  2     2020-01-20  G1226_20200120_3        G1226            3.0
#  3     2020-01-20  G1226_20200120_4        G1226            4.0
#  4     2020-01-20  G1226_20200120_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-20  G868_20200120_24         G868           24.0
#  1109  2020-01-20  G868_20200120_25         G868           25.0
#  1110  2020-01-20  G868_20200120_26         G868           26.0
#  1111  2020-01-20  G868_20200120_27         G868           27.0
#  1112  2020-01-20  G868_20200120_28         G868           28.0
#
# ...
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station       46
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station       65
#  1110       Minchinan Railway Station      Huashanbei Railway Station      194
#  1111      Huashanbei Railway Station       Weinanbei Railway Station       58
#  1112       Weinanbei Railway Station         Xianbei Railway Station       63
#
#        arrival_delay  departure_delay  major_holiday
#  0                 0               -1          False
#  1                -3               -1          False
#  2                -1               -1          False
#  3                 2                1          False
#  4                 1                0          False
#  ...             ...              ...            ...
#  1108              3                3          False
#  1109              4                4          False
#  1110              6                5          False
#  1111              4                3          False
#  1112              3                1          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-22  G1226_20200122_1        G1226            1.0
#  1     2020-01-22  G1226_20200122_2        G1226            2.0
#  2     2020-01-22  G1226_20200122_3        G1226            3.0
#  3     2020-01-22  G1226_20200122_4        G1226            4.0
#  4     2020-01-22  G1226_20200122_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-22  G868_20200122_24         G868           24.0
#  1109  2020-01-22  G868_20200122_25         G868           25.0
#  1110  2020-01-22  G868_20200122_26         G868           26.0
#  1111  2020-01-22  G868_20200122_27         G868           27.0
#  1112  2020-01-22  G868_20200122_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -1.0             -1.0          False
#  2               0.0              0.0          False
#  3               2.0              1.0          False
#  4               2.0              1.0          False
#  ...             ...              ...            ...
#  1108           -1.0             -1.0          False
#  1109           -1.0             -1.0          False
#  1110            0.0             -1.0          False
#  1111           -1.0             -2.0          False
#  1112           -2.0             -1.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-23  G1226_20200123_1        G1226            1.0
#  1     2020-01-23  G1226_20200123_2        G1226            2.0
#  2     2020-01-23  G1226_20200123_3        G1226            3.0
#  3     2020-01-23  G1226_20200123_4        G1226            4.0
#  4     2020-01-23  G1226_20200123_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1108  2020-01-23  G868_20200123_24         G868           24.0
#  1109  2020-01-23  G868_20200123_25         G868           25.0
#  1110  2020-01-23  G868_20200123_26         G868           26.0
#  1111  2020-01-23  G868_20200123_27         G868           27.0
#  1112  2020-01-23  G868_20200123_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1108     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1109  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1110       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1111      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1112       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2              -1.0             -1.0          False
#  3               1.0              0.0          False
#  4               0.0             -1.0          False
#  ...             ...              ...            ...
#  1108           -1.0             -1.0          False
#  1109           -1.0             -1.0          False
#  1110            0.0             -1.0          False
#  1111           -1.0             -2.0          False
#  1112           -1.0             -2.0          False
#
#  [1113 rows x 10 columns],
#              date           ride_id train_number  station_order  \
#  0     2020-01-24  G1226_20200124_1        G1226            1.0
#  1     2020-01-24  G1226_20200124_2        G1226            2.0
#  2     2020-01-24  G1226_20200124_3        G1226            3.0
#  3     2020-01-24  G1226_20200124_4        G1226            4.0
#  4     2020-01-24  G1226_20200124_5        G1226            5.0
#  ...          ...               ...          ...            ...
#  1051  2020-01-24  G868_20200124_24         G868           24.0
#  1052  2020-01-24  G868_20200124_25         G868           25.0
#  1053  2020-01-24  G868_20200124_26         G868           26.0
#  1054  2020-01-24  G868_20200124_27         G868           27.0
#  1055  2020-01-24  G868_20200124_28         G868           28.0
#
#                          station_name                      to_station  mileage  \
#  0        Shenyangbei Railway Station        Shenyang Railway Station      5.0
#  1           Shenyang Railway Station        Liaoyang Railway Station     65.0
#  2           Liaoyang Railway Station        Anshanxi Railway Station     30.0
#  3           Anshanxi Railway Station      Haichengxi Railway Station     39.0
#  4         Haichengxi Railway Station          Panjin Railway Station     66.0
#  ...                              ...                             ...      ...
#  1051     Zhengzhouxi Railway Station  Luoyanglongmen Railway Station     46.0
#  1052  Luoyanglongmen Railway Station       Minchinan Railway Station     65.0
#  1053       Minchinan Railway Station      Huashanbei Railway Station    194.0
#  1054      Huashanbei Railway Station       Weinanbei Railway Station     58.0
#  1055       Weinanbei Railway Station         Xianbei Railway Station     63.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0           True
#  1              -2.0             -1.0           True
#  2              -1.0             -1.0           True
#  3               1.0              0.0           True
#  4               0.0             -1.0           True
#  ...             ...              ...            ...
#  1051           -1.0             -2.0           True
#  1052           -1.0             -1.0           True
#  1053            0.0             -1.0           True
#  1054           -1.0             -2.0           True
#  1055           -2.0             -2.0           True
#
#  [1056 rows x 10 columns],
#             date            ride_id train_number  station_order  \
#  0    2020-01-25   G1226_20200125_1        G1226            1.0
#  1    2020-01-25   G1226_20200125_2        G1226            2.0
#  2    2020-01-25   G1226_20200125_3        G1226            3.0
#  3    2020-01-25   G1226_20200125_4        G1226            4.0
#  4    2020-01-25   G1226_20200125_5        G1226            5.0
#  ..          ...                ...          ...            ...
#  991  2020-01-25  G7592_20200125_20        G7592           20.0
#  992  2020-01-25  G7592_20200125_21        G7592           21.0
#  993  2020-01-25  G7592_20200125_22        G7592           22.0
#  994  2020-01-25  G7592_20200125_23        G7592           23.0
#  995  2020-01-25  G7592_20200125_24        G7592           24.0
#
#                       station_name                    to_station  mileage  \
#  0     Shenyangbei Railway Station      Shenyang Railway Station      5.0
#  1        Shenyang Railway Station      Liaoyang Railway Station     65.0
#  2        Liaoyang Railway Station      Anshanxi Railway Station     30.0
#  3        Anshanxi Railway Station    Haichengxi Railway Station     39.0
#  4      Haichengxi Railway Station        Panjin Railway Station     66.0
#  ..                            ...                           ...      ...
#  991    Nanjingnan Railway Station   Jiangningxi Railway Station     10.0
#  992   Jiangningxi Railway Station  Maanshandong Railway Station     32.0
#  993  Maanshandong Railway Station          Wuhu Railway Station     43.0
#  994          Wuhu Railway Station    Fanchangxi Railway Station     41.0
#  995    Fanchangxi Railway Station      Tongling Railway Station     35.0
#
#       arrival_delay  departure_delay  major_holiday
#  0              0.0             -1.0           True
#  1             -2.0             -1.0           True
#  2              0.0              0.0           True
#  3              2.0              1.0           True
#  4              2.0              1.0           True
#  ..             ...              ...            ...
#  991            0.0              0.0           True
#  992            0.0              0.0           True
#  993            0.0             -1.0           True
#  994           -1.0             -1.0           True
#  995           -3.0             -1.0           True
#
#  [996 rows x 10 columns],
#              date            ride_id train_number  station_order  \
#  0     2020-01-26   G1226_20200126_1        G1226            1.0
#  1     2020-01-26   G1226_20200126_2        G1226            2.0
#  2     2020-01-26   G1226_20200126_3        G1226            3.0
#  3     2020-01-26   G1226_20200126_4        G1226            4.0
#  4     2020-01-26   G1226_20200126_5        G1226            5.0
#  ...          ...                ...          ...            ...
#  1039  2020-01-26  G7592_20200126_20        G7592           20.0
#  1040  2020-01-26  G7592_20200126_21        G7592           21.0
#  1041  2020-01-26  G7592_20200126_22        G7592           22.0
#  1042  2020-01-26  G7592_20200126_23        G7592           23.0
#  1043  2020-01-26  G7592_20200126_24        G7592           24.0
#
#                        station_name                    to_station  mileage  \
#  0      Shenyangbei Railway Station      Shenyang Railway Station      5.0
#  1         Shenyang Railway Station      Liaoyang Railway Station     65.0
#  2         Liaoyang Railway Station      Anshanxi Railway Station     30.0
#  3         Anshanxi Railway Station    Haichengxi Railway Station     39.0
#  4       Haichengxi Railway Station        Panjin Railway Station     66.0
#  ...                            ...                           ...      ...
#  1039    Nanjingnan Railway Station   Jiangningxi Railway Station     10.0
#  1040   Jiangningxi Railway Station  Maanshandong Railway Station     32.0
#  1041  Maanshandong Railway Station          Wuhu Railway Station     43.0
#  1042          Wuhu Railway Station    Fanchangxi Railway Station     41.0
#  1043    Fanchangxi Railway Station      Tongling Railway Station     35.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2              -1.0             -1.0          False
#  3               0.0             -1.0          False
#  4               0.0             -1.0          False
#  ...             ...              ...            ...
#  1039            0.0              0.0          False
#  1040            0.0             -1.0          False
#  1041           -1.0             -1.0          False
#  1042           -1.0             -1.0          False
#  1043           -3.0             -1.0          False
#
#  [1044 rows x 10 columns],
#              date            ride_id train_number  station_order  \
#  0     2020-01-27   G1226_20200127_1        G1226            1.0
#  1     2020-01-27   G1226_20200127_2        G1226            2.0
#  2     2020-01-27   G1226_20200127_3        G1226            3.0
#  3     2020-01-27   G1226_20200127_4        G1226            4.0
#  4     2020-01-27   G1226_20200127_5        G1226            5.0
#  ...          ...                ...          ...            ...
#  1077  2020-01-27  G7592_20200127_20        G7592           20.0
#  1078  2020-01-27  G7592_20200127_21        G7592           21.0
#  1079  2020-01-27  G7592_20200127_22        G7592           22.0
#  1080  2020-01-27  G7592_20200127_23        G7592           23.0
#  1081  2020-01-27  G7592_20200127_24        G7592           24.0
#
#                        station_name                    to_station  mileage  \
#  0      Shenyangbei Railway Station      Shenyang Railway Station      5.0
#  1         Shenyang Railway Station      Liaoyang Railway Station     65.0
#  2         Liaoyang Railway Station      Anshanxi Railway Station     30.0
#  3         Anshanxi Railway Station    Haichengxi Railway Station     39.0
#  4       Haichengxi Railway Station        Panjin Railway Station     66.0
#  ...                            ...                           ...      ...
#  1077    Nanjingnan Railway Station   Jiangningxi Railway Station     10.0
#  1078   Jiangningxi Railway Station  Maanshandong Railway Station     32.0
#  1079  Maanshandong Railway Station          Wuhu Railway Station     43.0
#  1080          Wuhu Railway Station    Fanchangxi Railway Station     41.0
#  1081    Fanchangxi Railway Station      Tongling Railway Station     35.0
#
#        arrival_delay  departure_delay  major_holiday
#  0               0.0             -1.0          False
#  1              -2.0             -1.0          False
#  2              -1.0             -1.0          False
#  3               2.0              1.0          False
#  4               1.0              0.0          False
#  ...             ...              ...            ...
#  1077            0.0              2.0          False
#  1078            2.0              1.0          False
#  1079            0.0             -1.0          False
#  1080           -1.0             -1.0          False
#  1081           -2.0             -1.0          False
#
#  [1082 rows x 10 columns]]

# %% [markdown]
# ### Task 3
#
# Concatenate the DataFrames in `railway_delays_dfs` into a single DataFrame named `railway_delays_full`. Print summary information about `railway_delays_full`.
#
# What do you notice about the columns in our fully concatenated DataFrame?

# %%
railway_delays_full = pd.concat(railway_delays_df)
railway_delays_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29717 entries, 0 to 1081
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               28604 non-null  object
#  1   ride_id            28604 non-null  object
#  2   train_number       28604 non-null  object
#  3   station_order      28604 non-null  float64
#  4   station_name       27491 non-null  object
#  5   to_station         28604 non-null  object
#  6   mileage            28604 non-null  float64
#  7   arrival_delay      28604 non-null  float64
#  8   departure_delay    28604 non-null  float64
#  9   major_holiday      28604 non-null  object
#  10  DATE               1113 non-null   object
#  11  RIDE_ID            1113 non-null   object
#  12  TRAIN_NUMBER       1113 non-null   object
#  13  STATION_ORDER      1113 non-null   float64
#  14  STATION_NAME       1113 non-null   object
#  15  TO_STATION         1113 non-null   object
#  16  MILEAGE            1113 non-null   float64
#  17  ARRIVAL_DELAY      1113 non-null   float64
#  18  DEPARTURE_DELAY    1113 non-null   float64
#  19  MAJOR_HOLIDAY      1113 non-null   object
#  20  station_name       1113 non-null   object
# dtypes: float64(8), object(13)
# memory usage: 5.0+ MB

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What happened when we concatenated all of the DataFrames? Toggle to check!</i></summary>
#
# Vertically concatenating all of the DataFrames in `railway_delays_dfs` resulted in duplicate columns. The `.info()` output tells us that each column name appears at least twice. One set of names is lowercased and the other is uppercased. We also see the final column `station_name` is another duplicate that probably resulted from the presence of extra whitespaces in its name.
#
# These discrepancies are most likely due to individual DataFrames containing a different set of column names. Since Python and pandas are case-sensitive, we'll need to standardize the column names in every DataFrame before concatenation.
# </details>

# %% [markdown]
# ### Task 4
#
# Standardize the column names in each of the railway delay DataFrames by
#
# - *lowercasing* each column name
# - *removing* any extra whitespaces
#
# Use a `for` loop to automate this process.
#
# After standardizing the names, re-concatenate the cleaned DataFrames into a single DataFrame named `railway_delays_full` and preview the first five rows.

# %%
new_col_names = []
for col in railway_delays_full.columns:
    new_col_names.append(col.strip().lower())
railway_delays_full.columns = new_col_names
railway_delays_full
# Out:
#             date            ride_id train_number station_order  \
# 0     2020-01-01   G1226_20200101_1        G1226           1.0
# 1     2020-01-01   G1226_20200101_2        G1226           2.0
# 2     2020-01-01   G1226_20200101_3        G1226           3.0
# 3     2020-01-01   G1226_20200101_4        G1226           4.0
# 4     2020-01-01   G1226_20200101_5        G1226           5.0
# ...          ...                ...          ...           ...
# 1077  2020-01-27  G7592_20200127_20        G7592          20.0
# 1078  2020-01-27  G7592_20200127_21        G7592          21.0
# 1079  2020-01-27  G7592_20200127_22        G7592          22.0
# 1080  2020-01-27  G7592_20200127_23        G7592          23.0
# 1081  2020-01-27  G7592_20200127_24        G7592          24.0
#
#                       station_name                    to_station mileage  \
# 0      Shenyangbei Railway Station      Shenyang Railway Station     5.0
# 1         Shenyang Railway Station      Liaoyang Railway Station    65.0
# 2         Liaoyang Railway Station      Anshanxi Railway Station    30.0
# 3         Anshanxi Railway Station    Haichengxi Railway Station    39.0
# 4       Haichengxi Railway Station        Panjin Railway Station    66.0
# ...                            ...                           ...     ...
# 1077    Nanjingnan Railway Station   Jiangningxi Railway Station    10.0
# 1078   Jiangningxi Railway Station  Maanshandong Railway Station    32.0
# 1079  Maanshandong Railway Station          Wuhu Railway Station    43.0
# 1080          Wuhu Railway Station    Fanchangxi Railway Station    41.0
# 1081    Fanchangxi Railway Station      Tongling Railway Station    35.0
#
#       arrival_delay  departure_delay  major_holiday  ... ride_id train_number  \
# 0               0.0             -1.0           True  ...     NaN          NaN
# 1              -2.0              2.0           True  ...     NaN          NaN
# 2               4.0              4.0           True  ...     NaN          NaN
# 3               5.0              4.0           True  ...     NaN          NaN
# 4               5.0              4.0           True  ...     NaN          NaN
# ...             ...              ...            ...  ...     ...          ...
# 1077            0.0              2.0          False  ...     NaN          NaN
# 1078            2.0              1.0          False  ...     NaN          NaN
# 1079            0.0             -1.0          False  ...     NaN          NaN
# 1080           -1.0             -1.0          False  ...     NaN          NaN
# 1081           -2.0             -1.0          False  ...     NaN          NaN
#
#      station_order station_name to_station mileage  arrival_delay  \
# 0              NaN          NaN        NaN     NaN            NaN
# 1              NaN          NaN        NaN     NaN            NaN
# 2              NaN          NaN        NaN     NaN            NaN
# 3              NaN          NaN        NaN     NaN            NaN
# 4              NaN          NaN        NaN     NaN            NaN
# ...            ...          ...        ...     ...            ...
# 1077           NaN          NaN        NaN     NaN            NaN
# 1078           NaN          NaN        NaN     NaN            NaN
# 1079           NaN          NaN        NaN     NaN            NaN
# 1080           NaN          NaN        NaN     NaN            NaN
# 1081           NaN          NaN        NaN     NaN            NaN
#
#       departure_delay  major_holiday station_name
# 0                 NaN            NaN          NaN
# 1                 NaN            NaN          NaN
# 2                 NaN            NaN          NaN
# 3                 NaN            NaN          NaN
# 4                 NaN            NaN          NaN
# ...               ...            ...          ...
# 1077              NaN            NaN          NaN
# 1078              NaN            NaN          NaN
# 1079              NaN            NaN          NaN
# 1080              NaN            NaN          NaN
# 1081              NaN            NaN          NaN
#
# [29717 rows x 21 columns]

# %% [markdown]
# ### Task 5
# Let's continue cleaning the DataFrame. Use a for loop and `if/elif` statements to
#
# - *uppercase* all the object datatype columns
# - *strip* any hidden extra whitespace from object columns
# - *convert* all float datatype columns to integers
#
# Preview the cleaned DataFrame to confirm the transformations.

# %%
for col in railway_delays_full.columns:
    if railway_delays_full[col].dtypes is 'object':
        railway_delays_full[col] = railway_delays_full[col].str.strip().upper()
    elif railway_delays_full[col].dtypes is 'float64':
        railway_delays_full[col] = pd.to_numeric(railway_delays_full[col])
        
railway_delays_full.dtypes
# Out:
# date                  object
# ride_id               object
# train_number          object
# station_order        float64
# station_name          object
# to_station            object
# mileage              float64
# arrival_delay        float64
# departure_delay      float64
# major_holiday         object
# DATE                  object
# RIDE_ID               object
# TRAIN_NUMBER          object
# STATION_ORDER        float64
# STATION_NAME          object
# TO_STATION            object
# MILEAGE              float64
# ARRIVAL_DELAY        float64
# DEPARTURE_DELAY      float64
# MAJOR_HOLIDAY         object
# station_name          object
# dtype: object

# %% [markdown]
# ## Task Group 2 - Impact of Holiday Travel

# %% [markdown]
# ### Task 6
#
# Let's see if major holidays had an impact on railway delay times.
#
# Let's first see how many train rides actually occurred on major holidays compared to those that didn't. Use the `.value_counts()` method on the `major_holiday` column in `railway_delays_full`.
#
# There are four major holidays in our dataset. How does the number of trains on holidays compare to the number of trains on non-holidays?

# %%
railway_delays_full.dtypes
railway_delays_full['major_holiday'].value_counts()
# Out:
# False    24330
# True      4274
# Name: major_holiday, dtype: int64

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in Task 6? Toggle to check!</i></summary>
#
# There are `4274` individual station->station trips on the major holidays, averaging to `1068` per day.
#
# On the `23` non-holiday days in our dataset, there are `25443` station->station trips, averaging to `1106` per day.
#
# Based on this rough back-of-the-envelope calculation, there do seem to be slightly fewer individual trips on the holidays. But we'd have to look at data for more months or talk to a subject-matter expert to know for sure.
# </details>

# %% [markdown]
# ### Task 7
#
# Groupby `major_holiday` and calculate the average of `arrival_delay` and `departure_delay`.

# %%
holiday_delays = railway_delays_full.groupby('major_holiday').agg({'arrival_delay': 'mean',
                                                                  'departure_delay': 'mean'})
holiday_delays
# Out:
#                arrival_delay  departure_delay
# major_holiday
# False              23.390834        22.385368
# True               23.815863        22.924193

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover about the impact of holiday dates? Toggle to check!</i></summary>
#
# There doesn't seem to be a major difference in average delays, though both are slightly higher on holidays than non-holidays (by less than a minute). We'd have to dig into this further to know if this is a fluke of the dates we happen to be looking at or an actual statistical impact. Either way, it probably isn't enough to make a noticeable difference to riders!
#
# </details>

# %% [markdown]
# ## Task Group 3 - Impact of Distance Between Stations

# %% [markdown]
# ### Task 8
# The distance between stations could impact delays. For example, having further to travel might correspond to increased delays.
#
# In the next tasks, we'll investigate the distances between stations to see if there is an impact on train delays.
#
# Compute descriptive summary statistics on the distances from station to station by calling the `.describe()` method on the `mileage` column in `railway_delays_full`.
#
# What is the mean mileage (kilometers)?

# %%
railway_delays_full['mileage'].describe()
# Out:
# count    28604.000000
# mean        88.000734
# std         79.547856
# min          1.000000
# 25%         43.000000
# 50%         70.000000
# 75%        120.000000
# max       1410.000000
# Name: mileage, dtype: float64

# %% [markdown]
# ### Task 9
#
# Let's see if longer-than-average distances correspond to longer delays.
#
# Create a column `long_distance` that is `True` in any row with `mileage` greater than `88` (the average).

# %%
railway_delays_full['long_distance'] = railway_delays_full['mileage'] > 88
railway_delays_full.head()
# Out:
#          date           ride_id train_number  station_order  \
# 0  2020-01-01  G1226_20200101_1        G1226            1.0
# 1  2020-01-01  G1226_20200101_2        G1226            2.0
# 2  2020-01-01  G1226_20200101_3        G1226            3.0
# 3  2020-01-01  G1226_20200101_4        G1226            4.0
# 4  2020-01-01  G1226_20200101_5        G1226            5.0
#
#                   station_name                  to_station  mileage  \
# 0  Shenyangbei Railway Station    Shenyang Railway Station      5.0
# 1     Shenyang Railway Station    Liaoyang Railway Station     65.0
# 2     Liaoyang Railway Station    Anshanxi Railway Station     30.0
# 3     Anshanxi Railway Station  Haichengxi Railway Station     39.0
# 4   Haichengxi Railway Station      Panjin Railway Station     66.0
#
#    arrival_delay  departure_delay major_holiday  ... TRAIN_NUMBER  \
# 0            0.0             -1.0          True  ...          NaN
# 1           -2.0              2.0          True  ...          NaN
# 2            4.0              4.0          True  ...          NaN
# 3            5.0              4.0          True  ...          NaN
# 4            5.0              4.0          True  ...          NaN
#
#   STATION_ORDER STATION_NAME  TO_STATION MILEAGE ARRIVAL_DELAY  \
# 0           NaN          NaN         NaN     NaN           NaN
# 1           NaN          NaN         NaN     NaN           NaN
# 2           NaN          NaN         NaN     NaN           NaN
# 3           NaN          NaN         NaN     NaN           NaN
# 4           NaN          NaN         NaN     NaN           NaN
#
#    DEPARTURE_DELAY  MAJOR_HOLIDAY  station_name      long_distance
# 0              NaN            NaN                NaN         False
# 1              NaN            NaN                NaN         False
# 2              NaN            NaN                NaN         False
# 3              NaN            NaN                NaN         False
# 4              NaN            NaN                NaN         False
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Task 10
#
# Groupby `long_distance` and calculate the average `arrival_delay` and `departure_delay`.

# %%
distance_group = railway_delays_full.groupby('long_distance').agg({'arrival_delay': 'mean',
                                                                   'departure_delay': 'mean'})
distance_group
# Out:
#                arrival_delay  departure_delay
# long_distance
# False              16.598184        15.140762
# True               34.636589        34.412987

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover about the impact of distances between stations? Toggle to check!</i></summary>
#
# Trips with longer-than-average distance have almost double the mean delays of shorter-than-average trips. While we can't be 100% certain that the distances from station to station are a contributing factor to delay times, this is promising evidence to investigate this phenomenon further.
#
# </details>

# %% [markdown]
# ## Task Group 4 - Impact of Weather

# %% [markdown]
# ### Task 11
#
# Lastly, let's take a look at delays during ideal weather conditions and compare them to the delays during severe weather conditions.
#
# Import the CSV file `datasets/weather.csv` into a DataFrame named `weather` and preview the first five rows.

# %%
weather = pd.read_csv('datasets/weather.csv')
weather.head()
# Out:
#             ride_id                      wind weather  temperature
# 0  G1226_20200101_1    light winds from the N   sunny         -7.0
# 1  G1226_20200101_2    light winds from the N   sunny         -7.0
# 2  G1226_20200101_3    light winds from the N   sunny         -3.0
# 3  G1226_20200101_4  gentle breeze from the N   sunny         -3.0
# 4  G1226_20200101_5  gentle breeze from the N   sunny         -3.0

# %% [markdown]
# ### Task 12
#
# Let's clean `weather` by
# - *uppercasing* all of the text/object datatype columns
# - *stripping* whitespace from the object columns
# - *converting* all the float datatype columns to integers (we've checked that they should all be integers!)
#
# Use `for` loops and `if/elif` statements to automate this process.
#
# Preview the modified DataFrame.

# %%
for column in weather.columns:
    if weather[column].dtype == 'object':
        weather[column] = weather[column].str.upper()
        weather[column] = weather[column].str.strip()
    
    elif weather[column].dtype == 'float64':
        weather[column] = weather[column].astype('int64')

weather.head()
# Out:
#             ride_id                      wind weather  temperature
# 0  G1226_20200101_1    LIGHT WINDS FROM THE N   SUNNY           -7
# 1  G1226_20200101_2    LIGHT WINDS FROM THE N   SUNNY           -7
# 2  G1226_20200101_3    LIGHT WINDS FROM THE N   SUNNY           -3
# 3  G1226_20200101_4  GENTLE BREEZE FROM THE N   SUNNY           -3
# 4  G1226_20200101_5  GENTLE BREEZE FROM THE N   SUNNY           -3

# %% [markdown]
# ### Task 13
#
# Merge `weather` with `railway_delays_full` using the `ride_id` column. Use an inner merge and name the merged DataFrame `railway_delays_join_weather`. Preview the first five rows of the DataFrame.

# %%
railway_delays_join_weather = pd.merge(railway_delays_full, weather, on='ride_id', how='inner')
railway_delays_join_weather.head()
# Out:
#          date           ride_id train_number  station_order  \
# 0  2020-01-01  G1226_20200101_1        G1226            1.0
# 1  2020-01-01  G1226_20200101_2        G1226            2.0
# 2  2020-01-01  G1226_20200101_3        G1226            3.0
# 3  2020-01-01  G1226_20200101_4        G1226            4.0
# 4  2020-01-01  G1226_20200101_5        G1226            5.0
#
#                   station_name                  to_station  mileage  \
# 0  Shenyangbei Railway Station    Shenyang Railway Station      5.0
# 1     Shenyang Railway Station    Liaoyang Railway Station     65.0
# 2     Liaoyang Railway Station    Anshanxi Railway Station     30.0
# 3     Anshanxi Railway Station  Haichengxi Railway Station     39.0
# 4   Haichengxi Railway Station      Panjin Railway Station     66.0
#
#    arrival_delay  departure_delay major_holiday  ... TO_STATION MILEAGE  \
# 0            0.0             -1.0          True  ...        NaN     NaN
# 1           -2.0              2.0          True  ...        NaN     NaN
# 2            4.0              4.0          True  ...        NaN     NaN
# 3            5.0              4.0          True  ...        NaN     NaN
# 4            5.0              4.0          True  ...        NaN     NaN
#
#   ARRIVAL_DELAY  DEPARTURE_DELAY MAJOR_HOLIDAY station_name       \
# 0           NaN              NaN           NaN               NaN
# 1           NaN              NaN           NaN               NaN
# 2           NaN              NaN           NaN               NaN
# 3           NaN              NaN           NaN               NaN
# 4           NaN              NaN           NaN               NaN
#
#    long_distance                      wind  weather temperature
# 0          False    LIGHT WINDS FROM THE N    SUNNY          -7
# 1          False    LIGHT WINDS FROM THE N    SUNNY          -7
# 2          False    LIGHT WINDS FROM THE N    SUNNY          -3
# 3          False  GENTLE BREEZE FROM THE N    SUNNY          -3
# 4          False  GENTLE BREEZE FROM THE N    SUNNY          -3
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Task 14
#
# Groupby the `weather` column, and calculate the average of `arrival_delay` and `departure_delay`. Sort the result from highest `arrival_delay` to lowest.

# %%
weather_grouped = railway_delays_join_weather.groupby('weather').agg({'arrival_delay': 'mean',
                                                                      'departure_delay': 'mean'})
weather_grouped
# Out:
#                         arrival_delay  departure_delay
# weather
# BLIZZARD                   314.666667       314.666667
# CLOUDY                      28.245066        27.157444
# DOWNPOUR                     2.571429         1.771429
# FOG                          0.701613         0.048387
# HAZE                         0.501946         0.163424
# HEAVY HAZE                  -0.125000        -0.166667
# HEAVY SNOW                  79.289157        78.590361
# LIGHT RAIN                  14.886330        13.686517
# LIGHT SNOW                  51.291667        50.772569
# LIGHT TO MODERATE RAIN       3.455197         1.483871
# MODERATE HAZE                0.650943         0.490566
# MODERATE RAIN               39.685804        38.501044
# MODERATE SNOW               67.816794        66.977099
# MODERATE TO HEAVY RAIN       0.833333         0.333333
# OVERCAST                    19.017050        18.426418
# SHOWERS                      7.551724         7.195402
# SLEET                       39.614767        39.579454
# SNOW SHOWERS                 4.328125         3.875000
# SUNNY                       22.880296        21.694069

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover about the impact of weather? Toggle to check!</i></summary>
#
# There is a noticeable difference in delays based on weather conditions.
#
# - Severe weather conditions like blizzards and heavy snow saw a significant increase in delay times
# - Ideal weather conditions like sunny and rainy conditions saw shorter delay times
# - Fog and hazy weather conditions had the lowest delay times
#
# The last bullet point is perhaps the most interesting. Can you think of any reasons why fog would have lower delays than sunny conditions?
#
# </details>

# %% [markdown]
# There's definitely more insights to discover from this real-world dataset. Feel free to continue exploring here, or [download the source dataset](https://figshare.com/articles/dataset/A_high-speed_railway_network_dataset_from_train_operation_records_and_weather_data/15087882/4), which contains several more months of high-speed rail data!
